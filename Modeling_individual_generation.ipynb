# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Transformed_dataset.csv')

# %%
df.head(10)
# Out:
#   Date_Timestamp  DayOfWeek  Month  HourOfDay  Consumption_B1  Consumption_B2  \
# 0  1/1/2019 0:30          1      1          0      263.934730      119.965555
# 1  1/1/2019 1:30          1      1          1      261.381617      126.873583
# 2  1/1/2019 2:30          1      1          2      289.598378      130.980467
# 3  1/1/2019 3:30          1      1          3      340.806009      143.535150
# 4  1/1/2019 4:30          1      1          4      399.536718      174.588548
# 5  1/1/2019 5:30          1      1          5      359.570304      251.327078
# 6  1/1/2019 6:30          1      1          6      352.059444      247.050640
# 7  1/1/2019 7:30          1      1          7      344.880960      239.038966
# 8  1/1/2019 8:30          1      1          8      329.569168      237.915319
# 9  1/1/2019 9:30          1      1          9      314.838795      230.916968
#
#    Consumption_B3  Generation_1  Generation_2  Generation_3  Gb(i)  Gd(i)  \
# 0      100.382488      0.000000      0.000000      0.000000    0.0   0.00
# 1       98.777157      0.000000      0.000000      0.000000    0.0   0.00
# 2      109.956200      0.000000      0.000000      0.000000    0.0   0.00
# 3      129.512557      0.000000      0.000000      0.000000    0.0   0.00
# 4      150.485312      0.000000      0.000000      0.000000    0.0   0.00
# 5      135.929211      0.000000      0.000000      0.000000    0.0   0.00
# 6      147.602814      0.000000      0.000000      0.000000    0.0  15.29
# 7      147.823253      0.000000      0.650407      0.000000    0.0  38.27
# 8      135.971290     14.358974    254.634146     17.341256    0.0  75.57
# 9      129.750366     70.618401    644.552846     85.285463    0.0  93.85
#
#    Gr(i)  Temperature (c)  relative_humidity_2m (%)  dew_point_2m (°C)  \
# 0   0.00             0.24                        87                -1.7
# 1   0.00             0.33                        87                -1.6
# 2   0.00             0.36                        88                -1.5
# 3   0.00             0.21                        88                -1.6
# 4   0.00             0.03                        88                -1.7
# 5   0.00            -0.49                        91                -1.9
# 6   0.58            -0.56                        90                -2.1
# 7   1.44             0.05                        90                -1.5
# 8   2.84            -0.19                        92                -1.4
# 9   3.53             0.43                        88                -1.3
#
#    precipitation (mm)  cloud_cover (%)  wind_speed_10m (km/h)  \
# 0                 0.0               56                    7.2
# 1                 0.0              100                    7.6
# 2                 0.0               94                    5.9
# 3                 0.0               88                    5.5
# 4                 0.0               81                    6.4
# 5                 0.0               67                    5.1
# 6                 0.0               75                    4.8
# 7                 0.0               86                    3.2
# 8                 0.0               89                    4.3
# 9                 0.0               80                    4.2
#
#    Total_Consumption
# 0         484.282773
# 1         487.032358
# 2         530.535045
# 3         613.853717
# 4         724.610577
# 5         746.826593
# 6         746.712898
# 7         731.743179
# 8         703.455776
# 9         675.506128

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Solar Generation Prediction
# ## Building 1

# %%
df['Total_Generation'] = df['Generation_1'] + df['Generation_2'] + df['Generation_3']

# %%
X_bg1 = df.drop(['Date_Timestamp','Total_Consumption','Total_Generation','Generation_1','Generation_2','Generation_3'], axis=1)
y_bg1 = df['Generation_1']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_bg1, y_bg1, test_size=0.042, random_state=42, shuffle=False)

# %%
# Define the hyperparameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'learning_rate': [0.05, 0.1]
}

# Initialize the XGBoost regressor
xgbr = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Initialize GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgbr, param_grid=param_grid_xgb, cv=5, scoring='neg_mean_squared_error')

# Fit the XGBoost model with the training data
grid_search_xgb.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params_xgb = grid_search_xgb.best_params_
print("Best XGBoost Hyperparameters:", best_params_xgb)

# Use the best XGBoost model for prediction
best_xgb_model = grid_search_xgb.best_estimator_
y_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate the XGBoost model
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f"XGBoost RMSE: {rmse_xgb}")

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
print(f"XGBoost MAE: {mae_xgb}")
# Out:
# Best XGBoost Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# XGBoost RMSE: 53.15652173013724
# XGBoost MAE: 26.32154255078495

# %%
predictions_df = pd.DataFrame({'Predicted Values': y_pred_xgb})
predictions_df.to_csv('b1_generation_pred.csv', index=False)

# %%
#Plotting the actual vs predicted values for the test set
plt.figure(figsize=(20, 6))
y_test1 = y_test.to_numpy()
plt.plot(y_test1, label='Actual')
plt.plot(y_pred_xgb, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted value")
plt.show()

# %% [markdown]
# ## Building 2

# %%
X_bg2 = df.drop(['Date_Timestamp','Total_Consumption','Total_Generation','Generation_1','Generation_2','Generation_3'], axis=1)
y_bg2 = df['Generation_2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_bg2, y_bg2, test_size=0.042, random_state=42, shuffle=False)

# %%
# Define the hyperparameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'learning_rate': [0.05, 0.1]
}

# Initialize the XGBoost regressor
xgbr = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Initialize GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgbr, param_grid=param_grid_xgb, cv=5, scoring='neg_mean_squared_error')

# Fit the XGBoost model with the training data
grid_search_xgb.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params_xgb = grid_search_xgb.best_params_
print("Best XGBoost Hyperparameters:", best_params_xgb)

# Use the best XGBoost model for prediction
best_xgb_model = grid_search_xgb.best_estimator_
y_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate the XGBoost model
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f"XGBoost RMSE: {rmse_xgb}")

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
print(f"XGBoost MAE: {mae_xgb}")
# Out:
# Best XGBoost Hyperparameters: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
# XGBoost RMSE: 140.80637914032985
# XGBoost MAE: 72.58328228168023

# %%
predictions_df = pd.DataFrame({'Predicted Values': y_pred_xgb})
predictions_df.to_csv('b2_generation_pred.csv', index=False)

# %%
#Plotting the actual vs predicted values for the test set
plt.figure(figsize=(20, 6))
y_test1 = y_test.to_numpy()
plt.plot(y_test1, label='Actual')
plt.plot(y_pred_xgb, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted value")
plt.show()

# %% [markdown]
# ## Building 3

# %%
X_bg3 = df.drop(['Date_Timestamp','Total_Consumption','Total_Generation','Generation_1','Generation_2','Generation_3'], axis=1)
y_bg3 = df['Generation_3']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_bg3, y_bg3, test_size=0.042, random_state=42, shuffle=False)

# %%
# Define the hyperparameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'learning_rate': [0.05, 0.1]
}

# Initialize the XGBoost regressor
xgbr = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Initialize GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgbr, param_grid=param_grid_xgb, cv=5, scoring='neg_mean_squared_error')

# Fit the XGBoost model with the training data
grid_search_xgb.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params_xgb = grid_search_xgb.best_params_
print("Best XGBoost Hyperparameters:", best_params_xgb)

# Use the best XGBoost model for prediction
best_xgb_model = grid_search_xgb.best_estimator_
y_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate the XGBoost model
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f"XGBoost RMSE: {rmse_xgb}")

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
print(f"XGBoost MAE: {mae_xgb}")
# Out:
# Best XGBoost Hyperparameters: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
# XGBoost RMSE: 63.881257732114705
# XGBoost MAE: 31.534814697712022

# %%
predictions_df = pd.DataFrame({'Predicted Values': y_pred_xgb})
predictions_df.to_csv('b3_generation_pred.csv', index=False)

# %%
#Plotting the actual vs predicted values for the test set
plt.figure(figsize=(20, 6))
y_test1 = y_test.to_numpy()
plt.plot(y_test1, label='Actual')
plt.plot(y_pred_xgb, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted value")
plt.show()

# %% [markdown]
# ## Aggregate Model

# %%
X_gen_agg = df.drop(['Date_Timestamp','Total_Generation', 'Total_Consumption','Generation_1','Generation_3','Consumption_B1','Consumption_B2','Consumption_B3'], axis=1)
y_gen_agg = df['Total_Generation']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_gen_agg, y_gen_agg, test_size=0.042, random_state=42, shuffle=False)

# %%
# Define the hyperparameter grid for XGBoost
param_grid_xgb = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'learning_rate': [0.05, 0.1]
}

# Initialize the XGBoost regressor
xgbr = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Initialize GridSearchCV for XGBoost
grid_search_xgb = GridSearchCV(estimator=xgbr, param_grid=param_grid_xgb, cv=5, scoring='neg_mean_squared_error')

# Fit the XGBoost model with the training data
grid_search_xgb.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params_xgb = grid_search_xgb.best_params_
print("Best XGBoost Hyperparameters:", best_params_xgb)

# Use the best XGBoost model for prediction
best_xgb_model = grid_search_xgb.best_estimator_
y_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate the XGBoost model
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f"XGBoost RMSE: {rmse_xgb}")

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
print(f"XGBoost MAE: {mae_xgb}")
# Out:
# Best XGBoost Hyperparameters: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
# XGBoost RMSE: 75.45378337371064
# XGBoost MAE: 33.12208960109502

# %%
#Plotting the actual vs predicted values for the test set
plt.figure(figsize=(20, 6))
y_test1 = y_test.to_numpy()
plt.plot(y_test1, label='Actual')
plt.plot(y_pred_xgb, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted value")
plt.show()
